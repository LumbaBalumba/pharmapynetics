# %%
from pharmapynetics.models import EnsembledPBFTPK
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pharmapynetics.models import EnsembledPBFTPK
#
# ImportError: cannot import name 'EnsembledPBFTPK' from 'pharmapynetics.models' (/home/i3alumba/Projects/University/pharmapynetics/pharmapynetics/models.py)

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
t = np.array([0.,  0.5,  1.,  1.5,  2.,  3.,  3.33,  3.66,  4.,
              4.33,  4.66,  5.,  5.33,  5.66,  6.,  7.,  8., 10.,
              12., 16., 24., 48., 72., 96.])
X = np.array([0.,   98.3, 1150., 1340., 1480., 1400., 1350., 1440.,
              1360., 1340., 1180., 1100., 1080., 1090., 1060., 1030.,
              990.,  964., 1030.,  811.,  597.,  302.,  145.,   59.])

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
t_max = 25

# %%
t_current = t[t <= t_max]
X_current = X[t <= t_max]

# %%
model = EnsembledPBFTPK(n_models=2, l=9.0, clipped=True, t_max=t_max)

# %%
model.fit(t_current, X_current)

# %%
X_pred = model.sample(t)

# %%
plt.plot(t, X)
plt.plot(t, X_pred)
